# %%
from sfoda.dataio.conversion.readcars import load_cars_temp
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['axes.labelsize'] = 'medium'
plt.rcParams['font.size'] = 14

# %%
# Southern Ocean
X = np.array([141])
Y = np.array([-47])
Z = -np.arange(0,2000,10)
t = np.array([np.datetime64('2022-02-01'), np.datetime64('2021-06-01')])

# %%
Tcars = load_cars_temp('../../../CARS/temperature_cars2009a.nc',X, Y , Z, t )
Scars = load_cars_temp('../../../CARS/salinity_cars2009a.nc',X, Y , Z, t )

# %%
plt.figure()
plt.subplot(121)
plt.plot(Tcars[:,:,0], Z)
plt.plot(Tcars[:,:,1], Z)

plt.subplot(122)
plt.plot(Scars[:,:,0], Z)
plt.plot(Scars[:,:,1], Z)
plt.tight_layout()
